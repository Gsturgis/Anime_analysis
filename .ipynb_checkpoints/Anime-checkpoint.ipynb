# %%
import pandas as pd 
import bokeh as bp
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/anime.csv')

# %%
df.head()
# Out:
#    Anime-PlanetID                                           Name  \
# 0              10                           The Prince of Tennis
# 1             100                        Neon Genesis Evangelion
# 2            1000              Full Metal Panic! The Second Raid
# 3           10000                 22/7: Shampoo no Nioi ga Shita
# 4           10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
#
#        Alternative Name Rating Score Number Votes  \
# 0   Tennis no Ouji-sama        4.037        10889
# 1  Shinseiki Evangelion        4.248        54463
# 2               Unknown         4.35        23948
# 3               Unknown          2.8          131
# 4               Unknown        1.271           21
#
#                                                 Tags  \
# 0  Comedy, Drama, Shounen, Sports, Tennis, Based ...
# 1  Drama, Mecha, Sci Fi, Conspiracy, Kaijuu, Lone...
# 2  Action, Comedy, Mecha, Sci Fi, Shounen, Milita...
# 3                   Idols, School Life, CG Animation
# 4                                    Family Friendly
#
#                                      Content Warning   Type Episodes  \
# 0                                            Unknown     TV      178
# 1  Emotional Abuse, Explicit Violence, Mature The...     TV       26
# 2                          Explicit Violence, Nudity     TV       13
# 3                                            Unknown  Music        1
# 4                                            Unknown    Web        1
#
#    Finished Duration StartYear EndYear       Season  \
# 0      True  Unknown      2001    2005    Fall 2001
# 1      True  Unknown      1995    1996    Fall 1995
# 2      True  Unknown      2005    2005  Summer 2005
# 3      True        5      2018    2018      Unknown
# 4      True        2      2017    2017      Unknown
#
#                         Studios  \
# 0    Production I.G, Trans Arts
# 1  GAINAX, Tatsunoko Production
# 2               Kyoto Animation
# 3                       Unknown
# 4                Toei Animation
#
#                                             Synopsis  \
# 0  Meet Ryoma Echizen, the cocky prince of tennis...
# 1  In the future, a devastating event known as Se...
# 2  Half a year has passed since Sousuke Sagara to...
# 3  The idol group 22/7 perform the song Shampoo n...
# 4                 No synopsis yet - check back soon!
#
#                                                  Url
# 0  https://www.anime-planet.com/anime/the-prince-...
# 1  https://www.anime-planet.com/anime/neon-genesi...
# 2  https://www.anime-planet.com/anime/full-metal-...
# 3  https://www.anime-planet.com/anime/22-7-shampo...
# 4  https://www.anime-planet.com/anime/oshiri-tant...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16621 entries, 0 to 16620
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Anime-PlanetID    16621 non-null  int64
#  1   Name              16621 non-null  object
#  2   Alternative Name  16621 non-null  object
#  3   Rating Score      16621 non-null  object
#  4   Number Votes      16621 non-null  object
#  5   Tags              16621 non-null  object
#  6   Content Warning   16621 non-null  object
#  7   Type              16621 non-null  object
#  8   Episodes          16621 non-null  object
#  9   Finished          16621 non-null  bool
#  10  Duration          16621 non-null  object
#  11  StartYear         16621 non-null  object
#  12  EndYear           16621 non-null  object
#  13  Season            16621 non-null  object
#  14  Studios           16621 non-null  object
#  15  Synopsis          16615 non-null  object
#  16  Url               16621 non-null  object
# dtypes: bool(1), int64(1), object(15)
# memory usage: 2.0+ MB

# %%
df.replace({"Unknown":0}, inplace = True)

# %%
df = df.astype({'Episodes': 'int64'})

# %%
df_sorted= df.sort_values('Episodes',ascending=False)

# %%
df_sorted
# Out:
#        Anime-PlanetID                           Name Alternative Name  \
# 10333            4098                      Sazae-san                0
# 13839            7404               Nintama Rantarou                0
# 16251            9652                     Oyako Club                0
# 13854             742                Doraemon (1979)                0
# 2178            12039                      Ojarumaru  Prince Mackaroo
# ...               ...                            ...              ...
# 7129            16580                     Tesla Note                0
# 7132            16583    Peleliu: Rakuen no Guernica                0
# 7135            16586            Dance Dance Danseur                0
# 7137            16588  The Way of the Househusband 2   Gokushufudou 2
# 1839            11730                    Shikizakura                0
#
#       Rating Score Number Votes  \
# 10333        2.774          171
# 13839        3.527           87
# 16251        2.376           45
# 13854        3.388         2503
# 2178         3.185           27
# ...            ...          ...
# 7129             0            0
# 7132             0            0
# 7135             0            0
# 7137             0            0
# 1839             0            0
#
#                                                     Tags Content Warning  \
# 10333  Comedy, Slice of Life, Family Life, Based on a...               0
# 13839  Action, Adventure, Comedy, Shounen, Family Fri...               0
# 16251                             Comedy, Short Episodes               0
# 13854  Comedy, Shounen, Cats, Family Friendly, Non-Hu...               0
# 2178   Family Friendly, Short Episodes, Time Travel, ...               0
# ...                                                  ...             ...
# 7129   Action, Comedy, Sci Fi, Shounen, Based on a Manga               0
# 7132   Action, Shounen, Island, War, World War 2, Bas...               0
# 7135   Drama, Seinen, Ballet Dancing, Dancing, Based ...               0
# 7137   Comedy, Seinen, Slice of Life, Episodic, Gangs...               0
# 1839          Drama, Sci Fi, CG Animation, Original Work               0
#
#         Type  Episodes  Finished Duration StartYear EndYear     Season  \
# 10333     TV      2603     False        0      1969       0          0
# 13839     TV      2204     False       10      1993       0          0
# 16251     TV      1818      True        5      1994    2013          0
# 13854     TV      1787      True       11      1979    2005          0
# 2178      TV      1738     False       10      1998       0  Fall 1998
# ...      ...       ...       ...      ...       ...     ...        ...
# 7129      TV         0      True        0      2021    2021          0
# 7132   Other         0      True        0         0       0          0
# 7135      TV         0      True        0         0       0          0
# 7137     Web         0      True        0         0       0          0
# 1839      TV         0      True        0      2021    2021  Fall 2021
#
#                  Studios                                           Synopsis  \
# 10333              Eiken  Sazae Fuguta, married to Masuo and mother of T...
# 13839            Ajia-do  Rantarou, Shinbei and Kirimaru are ninja appre...
# 16251              Eiken                 No synopsis yet - check back soon!
# 13854  Shin-Ei Animation  Nobita is dumb, lazy, and slow, and as a resul...
# 2178              Gallop  In the Heian era, around 1000 years ago, a you...
# ...                  ...                                                ...
# 7129              Gambit  Mission T is an intelligence operation with a ...
# 7132                   0  Follows the daily lives of Japanese soldiers t...
# 7135                   0  Junpei Murao was fascinated with ballet as a c...
# 7137                   0     Second season of The Way of the Househusband .
# 1839         Sublimation                 No synopsis yet - check back soon!
#
#                                                      Url
# 10333       https://www.anime-planet.com/anime/sazae-san
# 13839  https://www.anime-planet.com/anime/nintama-ran...
# 16251      https://www.anime-planet.com/anime/oyako-club
# 13854   https://www.anime-planet.com/anime/doraemon-1979
# 2178        https://www.anime-planet.com/anime/ojarumaru
# ...                                                  ...
# 7129       https://www.anime-planet.com/anime/tesla-note
# 7132   https://www.anime-planet.com/anime/peleliu-rak...
# 7135   https://www.anime-planet.com/anime/dance-dance...
# 7137   https://www.anime-planet.com/anime/the-way-of-...
# 1839      https://www.anime-planet.com/anime/shikizakura
#
# [16621 rows x 17 columns]

# %%
x = df_sorted['Name'].head(20)
y = df_sorted['Episodes'].head(20)
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
plt.figure(figsize=(20,10))
plt.xlabel('Episodes')
plt.ylabel('Anime')
plt.barh(x,y,color=colors)
# Out:
# <BarContainer object of 20 artists>
